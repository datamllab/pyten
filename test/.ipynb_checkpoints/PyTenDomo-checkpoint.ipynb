# %% [markdown]
# # <center>PyTen Package Tutorial</center>
# #### <center>Texas A&M University HELIOS Group</center>

# %% [markdown]
# ## Quick Start

# %%
import pyten
# This is a quick start without prior input
[OriTensor, DeTensor, TenClass, RecTensor] = pyten.UI.helios()
# Out:
# Please choose the Scenario:
#  1. Basic Tensor Decomposition/Completion  2.Tensor Completion with Auxiliary Information 3.Dynamic Tensor Decomposition 0.Exit
# 0
# Successfully Exit

# %%
# Results
print OriTensor  # Original Tensor
print DeTensor.data  # Full Tensor reconstructed by decomposed matrices
print TenClass  # Final Decomposition Results e.g. Ttensor or Ktensor
print RecTensor.data  # Recovered Tensor (Completed Tensor)

# %% [markdown]
# ## Three UI Functions For Three Scenarios
# ### Scenario 1: Basic Tensor completion or decomposition.

# %%
[OriTensor, DeTensor, TenClass, RecTensor] = pyten.UI.basic()
# Out:
# Please input the FileName of the data:
# syntensor.csv
#
#
# Please choose the method you want to use to recover data(Input one number):
#  1. Tucker(ALS)  2.CP(ALS) 3.NNCP(Trace Norm + ADMM, Only For Recovery) 4.SiLRTC(Only For Recovery) 5.FaLRTC(Only For Recovery) 6.HaLRTC(Only For Recovery)  0.Exit
# 1
#
#
# If there are missing values in the file? (Input one number)
# 1. Yes, recover it  2.No, just decompose(Nonexistent number will be replaced by 0) 0.Exit
# 1
#
# The original Tensor is:
# [[[    nan     nan     nan     nan]
#   [ 0.0193     nan  0.023   0.0138]]
#
#  [[    nan  0.0209     nan  0.0192]
#   [ 0.2244  0.4468  0.4514  0.2389]]
#
#  [[    nan  0.4337  0.3854     nan]
#   [ 0.0098  0.0198  0.0199  0.0105]]]
#
# The Recovered Tensor is:
# [[[  5.36241697e-03   1.15809827e-02   2.41906083e-02   5.87321814e-03]
#   [  1.93000000e-02   3.13163947e-02   2.30000000e-02   1.38000000e-02]]
#
#  [[ -2.69199851e-03   2.09000000e-02   1.68218328e+00   1.92000000e-02]
#   [  2.24400000e-01   4.46800000e-01   4.51400000e-01   2.38900000e-01]]
#
#  [[ -5.83048413e-04   4.33700000e-01   3.85400000e-01   4.15785538e-03]
#   [  9.80000000e-03   1.98000000e-02   1.99000000e-02   1.05000000e-02]]]

# %% [markdown]
# ### Scenario 2: Tensor completion or decomposition with auxiliary information

# %%
[OriTensor, DeTensor, TenClass, RecTensor] = pyten.UI.auxiliary()
# Out:
# Please input the FileName of the Tensor data:
# syntensor.csv
#
#
# Please choose the method you want to use to recover data(Input one number):
#  1. AirCP  2.CMTF 0.Exit
# 1
#
#
# Please input all the modes that have Auxiliary Similarity Matrix (separate with space. Input 'None' if no auxiliary info.)
# None
# If there are missing values in the file? (Input one number)
# 1. Yes, recover it  2.No, just decompose(Nonexistent number will be replaced by 0) 0.Exit
# 1
# AirCP: iterations=1, difference=0.123439314385
#
# The original Tensor is:
# [[[    nan     nan     nan     nan]
#   [ 0.0193     nan  0.023   0.0138]]
#
#  [[    nan  0.0209     nan  0.0192]
#   [ 0.2244  0.4468  0.4514  0.2389]]
#
#  [[    nan  0.4337  0.3854     nan]
#   [ 0.0098  0.0198  0.0199  0.0105]]]
#
# The Recovered Tensor is:
# [[[  3.97746028e-21   3.51320770e-21   4.34299079e-21   2.56296065e-21]
#   [  1.93000000e-02   2.39905925e-20   2.30000000e-02   1.38000000e-02]]
#
#  [[  2.78455108e-20   2.09000000e-02   3.37187234e-20   1.92000000e-02]
#   [  2.24400000e-01   4.46800000e-01   4.51400000e-01   2.38900000e-01]]
#
#  [[  8.81164984e-21   4.33700000e-01   3.85400000e-01   4.90359521e-21]
#   [  9.80000000e-03   1.98000000e-02   1.99000000e-02   1.05000000e-02]]]
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/AirCP.py:50: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if simMats == None:

# %% [markdown]
# ### Scenario 3: Dynamic/Online/Streaming Tensor completion or decomposition

# %%
[OriTensor, DeTensor, TenClass, RecTensor] = pyten.UI.dynamic()
# Out:
# Please input the FileName of the data:
# syntensor.csv
#
#
# Please choose the method you want to use (Input one number):
#  1. onlineCP(only for decomposition)  2.OLSGD 0.Exit
# 1
#
#
# If there are former decomposition or recovery result (.npy file):
#  1. Yes  2.No 0.Exit
# 0
#
# CP_ALS:
#
# (' Iter %2d: f = %e f-delta = %7.1e\n', 87, 0.96801947647742581, 7.13133396779142e-09)
#
# The original Tensor is:
# [[[    nan     nan     nan     nan]
#   [ 0.0193     nan  0.023   0.0138]]
#
#  [[    nan  0.0209     nan  0.0192]
#   [ 0.2244  0.4468  0.4514  0.2389]]
#
#  [[    nan  0.4337  0.3854     nan]
#   [ 0.0098  0.0198  0.0199  0.0105]]]
#
# The Decomposed Result is:
# [array([[-0.00081028,  0.02831673],
#        [-0.00760506,  0.80312331],
#        [ 0.56600935,  0.0350537 ]]), array([[  8.67197773e-01,   3.05297445e-02],
#        [  5.57022276e-04,   8.27095577e-01]]), array([[ -5.09094815e-04,   3.37962554e-01],
#        [  8.81837582e-01,   6.72368962e-01],
#        [  7.84014665e-01,   6.79293430e-01],
#        [ -1.06846296e-03,   3.60511005e-01]])]
# If you want to save the result into .npy file):
#  1. Yes  2.No  0.Exit
# 2

# %% [markdown]
# ## Usage of Main Functions
# ### Function: create
# 1. Create Tensor Completion Problem

# %%
from pyten.tools import create  # Import the problem creation function

problem = 'basic'  # Problem Definition
siz = [20, 20, 20]  # Size of the Created Synthetic Tensor
r = [4, 4, 4]  # Rank of the Created Synthetic Tensor
miss = 0.8  # Missing Percentage
tp = 'CP'  # Solution Format (Creating Method) of the Created Synthetic Tensor
[X1, Omega1, sol1] = create(problem, siz, r, miss, tp)

# %% [markdown]
# ### Scenario 1: Basic Tensor Completion/Decomposition
# #### 1. Solve Synthetic Completion Problem

# %%
from pyten.tools import create  # Import the problem creation function

problem = 'basic'  # Define Problem As Basic Tensor Completion Problem
siz = [20, 20, 20]  # Size of the Created Synthetic Tensor
r = [4, 4, 4]  # Rank of the Created Synthetic Tensor
miss = 0.8  # Missing Percentage
tp = 'CP'  # Define Solution Format of the Created Synthetic Tensor As 'CP decomposition'
[X1, Omega1, sol1] = create(problem, siz, r, miss, tp)

# Basic Tensor Completion with methods: CP-ALS,Tucker-ALS, FaLRTC, SiLRTC, HaLRTC, TNCP
from pyten.method import *

r = 4  # Rank for CP-based methods
R = [4, 4, 4]  # Rank for tucker-based methods
# P-ALS
[T1, rX1] = cp_als(X1, r, Omega1)  # if no missing data just omit Omega1 by using [T1,rX1]=cp_als.cp_als(X1,r)
print sol1.totensor().data
print rX1.data
# Tucker-ALS
[T2, rX2] = tucker_als(X1, R, Omega1)  # if no missing data just omit Omega1
# FalRTC, SiLRTC, HaLRTC
rX3 = falrtc(X1, Omega1)
rX4 = silrtc(X1, Omega1)
rX5 = halrtc(X1, Omega1)
# TNCP
self1 = TNCP(X1, Omega1, rank=r)
self1.run()

# Error Testing
from pyten.tools import tenerror

realX = sol1.totensor()
[Err1, ReErr11, ReErr21] = tenerror(rX1, realX, Omega1)
[Err2, ReErr12, ReErr22] = tenerror(rX2, realX, Omega1)
[Err3, ReErr13, ReErr23] = tenerror(rX3, realX, Omega1)
[Err4, ReErr14, ReErr24] = tenerror(rX4, realX, Omega1)
[Err5, ReErr15, ReErr25] = tenerror(rX5, realX, Omega1)
[Err6, ReErr16, ReErr26] = tenerror(self1.X, realX, Omega1)
print ReErr21, ReErr22, ReErr23, ReErr24, ReErr25, ReErr26
# Out:
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/cp_als.py:21: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if Omega==None:
# CP_ALS:
#
# (' Iter %2d: f = %e f-delta = %7.1e\n', 1, 9.736308322709375)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 2, 7.3993297188768681)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 3, 5.5538730904110283)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 4, 4.2794484820434118)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 5, 3.3811403986840713)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 6, 2.7280038062944487)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 7, 2.2404994814633987)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 8, 1.8697367926505897)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 9, 1.5842642984481934)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 10, 1.3625373729369392)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 11, 1.1887968543571918)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 12, 1.0509450356301804)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 13, 0.93958470760557755)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 14, 0.84762998935301392)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 15, 0.77000207069492177)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 16, 0.70316594957752721)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 17, 0.644606481897251)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 18, 0.59244843875400011)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 19, 0.5452376924574428)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 20, 0.50178793085583673)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 21, 0.46111098337109119)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 22, 0.42248767060331183)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 23, 0.38558778741023203)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 24, 0.35047782443628156)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 25, 0.31747551857897693)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 26, 0.28694522376575449)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 27, 0.25914303013026324)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 28, 0.23415437138195397)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 29, 0.21190607576948509)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 30, 0.19221402717506095)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 31, 0.17483528111750637)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 32, 0.15950902118826252)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 33, 0.14598268186540928)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 34, 0.13402554603755559)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 35, 0.12343381673067412)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 36, 0.11403074965903898)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 37, 0.10566438116148355)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 38, 0.098204390569997663)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 39, 0.091538914008135353)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 40, 0.085571675740499065)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 41, 0.080219552715627154)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 42, 0.075410564958522691)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 43, 0.071082234417171486)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 44, 0.06718024260796171)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 45, 0.063657322419182025)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 46, 0.060472330692914564)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 47, 0.057589460301760612)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 48, 0.054977561058190801)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 49, 0.052609547225891853)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 50, 0.0504618756851734)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 51, 0.048514083281359852)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 52, 0.046748374973641982)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 53, 0.04514925649198142)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 54, 0.043703206617427992)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 55, 0.042398385165093713)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 56, 0.041224373432972916)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 57, 0.040171944389411483)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 58, 0.039232860267275863)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 59, 0.038399695542164658)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 60, 0.03766568350748159)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 61, 0.037024584821069899)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 62, 0.036470576489278178)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 63, 0.035998159779136688)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 64, 0.035602085520937236)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 65, 0.035277295199566482)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 66, 0.035018876157170462)
# (' Iter %2d: f = %e f-delta = %7.1e\n',
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/falrtc.py:46: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if Omega==None:
# FaLRTC: iterations = %d   difference=%f
# 1 [ 1.826953]
# FaLRTC: iterations = %d   difference=%f
# 2 [ 0.25718142]
# FaLRTC: iterations = %d   difference=%f
# 3 [ 0.26044105]
# FaLRTC: iterations = %d   difference=%f
# 4 [ 0.30627546]
# FaLRTC: iterations = %d   difference=%f
# 5 [ 0.30880571]
# FaLRTC: iterations = %d   difference=%f
# 6 [ 0.15616914]
# FaLRTC: iterations = %d   difference=%f
# 7 [ 0.13386103]
# FaLRTC: iterations = %d   difference=%f
# 8 [ 0.10297178]
# FaLRTC: iterations = %d   difference=%f
# 9 [ 0.06863772]
# FaLRTC: iterations = %d   difference=%f
# 10 [ 0.03677131]
# FaLRTC: iterations = %d   difference=%f
# 11 [ 0.01353523]
# FaLRTC: iterations = %d   difference=%f
# 12 [ 0.01112917]
# FaLRTC: iterations = %d   difference=%f
# 13 [ 0.01654712]
# FaLRTC: iterations = %d   difference=%f
# 14 [ 0.01660179]
# FaLRTC: iterations = %d   difference=%f
# 15 [ 0.01280307]
# FaLRTC: iterations = %d   difference=%f
# 16 [ 0.0085166]
# FaLRTC: iterations = %d   difference=%f
# 17 [ 0.00780242]
# FaLRTC: iterations = %d   difference=%f
# 18 [ 0.01010771]
# FaLRTC: iterations = %d   difference=%f
# 19 [ 0.01179033]
# FaLRTC: iterations = %d   difference=%f
# 20 [ 0.01172763]
# FaLRTC: iterations = %d   difference=%f
# 21 [ 0.01013569]
# FaLRTC: iterations = %d   difference=%f
# 22 [ 0.00766698]
# FaLRTC: iterations = %d   difference=%f
# 23 [ 0.00506615]
# FaLRTC: iterations = %d   difference=%f
# 24 [ 0.00298742]
# FaLRTC: iterations = %d   difference=%f
# 25 [ 0.00194837]
# FaLRTC: iterations = %d   difference=%f
# 26 [ 0.00184318]
# FaLRTC: iterations = %d   difference=%f
# 27 [ 0.00152738]
# FaLRTC: iterations = %d   difference=%f
# 28 [ 0.00166209]
# FaLRTC: iterations = %d   difference=%f
# 29 [ 0.00183369]
# FaLRTC: iterations = %d   difference=%f
# 30 [ 0.00202553]
# FaLRTC: iterations = %d   difference=%f
# 31 [ 0.00220615]
# FaLRTC: iterations = %d   difference=%f
# 32 [ 0.00232993]
# FaLRTC: iterations = %d   difference=%f
# 33 [ 0.00236183]
# FaLRTC: iterations = %d   difference=%f
# 34 [ 0.00228913]
# FaLRTC: iterations = %d   difference=%f
# 35 [ 0.00212136]
# FaLRTC: iterations = %d   difference=%f
# 36 [ 0.0018845]
# FaLRTC: iterations = %d   difference=%f
# 37 [ 0.00161374]
# FaLRTC: iterations = %d   difference=%f
# 38 [ 0.00134683]
# FaLRTC: iterations = %d   difference=%f
# 39 [ 0.00111818]
# FaLRTC: iterations = %d   difference=%f
# 40 [ 0.0009524]
# FaLRTC: iterations = %d   difference=%f
# 41 [ 0.00085658]
# FaLRTC: iterations = %d   difference=%f
# 42 [ 0.00081763]
# FaLRTC: iterations = %d   difference=%f
# 43 [ 0.00080928]
# FaLRTC: iterations = %d   difference=%f
# 44 [ 0.00081265]
# FaLRTC: iterations = %d   difference=%f
# 45 [ 0.00081872]
# FaLRTC: iterations = %d   difference=%f
# 46 [ 0.000824]
# FaLRTC: iterations = %d   difference=%f
# 47 [ 0.00082599]
# FaLRTC: iterations = %d   difference=%f
# 48 [ 0.00082149]
# FaLRTC: iterations = %d   difference=%f
# 49 [ 0.00080724]
# FaLRTC: iterations = %d   difference=%f
# 50 [ 0.00078132]
# FaLRTC: iterations = %d   difference=%f
# 51 [ 0.0007441]
# FaLRTC: iterations = %d   difference=%f
# 52 [ 0.00069829]
# FaLRTC: iterations = %d   difference=%f
# 53 [ 0.00064843]
# FaLRTC: iterations = %d   difference=%f
# 54 [ 0.00059976]
# FaLRTC: iterations = %d   difference=%f
# 55 [ 0.0005569]
# FaLRTC: iterations = %d   difference=%f
# 56 [ 0.00052262]
# FaLRTC: iterations = %d   difference=%f
# 57 [ 0.00049736]
# FaLRTC: iterations = %d   difference=%f
# 58 [ 0.00047962]
# FaLRTC: iterations = %d   difference=%f
# 59 [ 0.00046702]
# FaLRTC: iterations = %d   difference=%f
# 60 [ 0.00045737]
# FaLRTC: iterations = %d   difference=%f
# 61 [ 0.00044833]
# FaLRTC: iterations = %d   difference=%f
# 62 [ 0.00043831]
# FaLRTC: iterations = %d   difference=%f
# 63 [ 0.00042735]
# FaLRTC: iterations = %d   difference=%f
# 64 [ 0.00041574]
# FaLRTC: iterations = %d   difference=%f
# 65 [ 0.00040363]
# FaLRTC: iterations = %d   difference=%f
# 66 [ 0.00039097]
# FaLRTC: iterations = %d   difference=%f
# 67 [ 0.00037774]
# FaLRTC: iterations = %d   difference=%f
# 68 [ 0.00036413]
# FaLRTC: iterations = %d   difference=%f
# 69 [ 0.00035052]
# FaLRTC: iterations = %d   difference=%f
# 70 [ 0.00033743]
# FaLRTC: iterations = %d   difference=%f
# 71 [ 0.00032531]
# FaLRTC: iterations = %d   difference=%f
# 72 [ 0.00031439]
# FaLRTC: iterations = %d   difference=%f
# 73 [ 0.00030469]
# FaLRTC: iterations = %d   difference=%f
# 74 [ 0.00029607]
# FaLRTC: iterations = %d   difference=%f
# 75 [ 0.00028831]
# FaLRTC: iterations = %d   difference=%f
# 76 [ 0.00028118]
# FaLRTC: iterations = %d   difference=%f
# 77 [ 0.0002745]
# FaLRTC: iterations = %d   difference=%f
# 78 [ 0.00026811]
# FaLRTC: iterations = %d   difference=%f
# 79 [ 0.00026189]
# FaLRTC: iterations = %d   difference=%f
# 80 [ 0.00025574]
# FaLRTC: iterations = %d   difference=%f
# 81 [ 0.00024957]
# FaLRTC: iterations = %d   difference=%f
# 82 [ 0.00024337]
# FaLRTC: iterations = %d   difference=%f
# 83 [ 0.00023714]
# FaLRTC: iterations = %d   difference=%f
# 84 [ 0.00023093]
# FaLRTC: iterations = %d   difference=%f
# 85 [ 0.00022483]
# FaLRTC: iterations = %d   difference=%f
# 86 [ 0.00016551]
# FaLRTC: iterations = %d   difference=%f
# 87 [  9.39201710e-05]
# FaLRTC: iterations = %d   difference=%f
# 88 [  3.93835702e-05]
# FaLRTC: iterations = %d   difference=%f
# 89 [  4.58749077e-05]
# FaLRTC: iterations = %d   difference=%f
# 90 [  7.17871794e-05]
# FaLRTC: iterations = %d   difference=%f
# 91 [  8.48164700e-05]
# FaLRTC: iterations = %d   difference=%f
# 92 [  8.34496661e-05]
# FaLRTC: iterations = %d   difference=%f
# 93 [  7.03447487e-05]
# FaLRTC: iterations = %d   difference=%f
# 94 [  5.00365092e-05]
# FaLRTC: iterations = %d   difference=%f
# 95 [  2.87349295e-05]
# FaLRTC: iterations = %d   difference=%f
# 96 [  1.76614336e-05]
# FaLRTC: iterations = %d   difference=%f
# 97 [  2.46381285e-05]
# FaLRTC: iterations = %d   difference=%f
# 98 [  3.28665501e-05]
# FaLRTC: iterations = %d   difference=%f
# 99 [  3.57658329e-05]
# FaLRTC ends: total iterations = %d   difference=%f
#
# 100 [  3.32102864e-05]
# SiLRTC: iterations = %d   difference=%f
# 1 [ 0.10618281]
# SiLRTC: iterations = %d   difference=%f
# 2 [ 0.08153969]
# SiLRTC: iterations = %d   difference=%f
# 3 [ 0.06373537]
# SiLRTC: iterations = %d   difference=%f
# 4 [ 0.04954457]
# SiLRTC: iterations = %d   difference=%f
# 5 [ 0.03833348]
# SiLRTC: iterations = %d   difference=%f
# 6 [ 0.02958798]
# SiLRTC: iterations = %d   difference=%f
# 7 [ 0.02282286]
# SiLRTC: iterations = %d   difference=%f
# 8 [ 0.01761545]
# SiLRTC: iterations = %d   difference=%f
# 9 [ 0.01361709]
# SiLRTC: iterations = %d   difference=%f
# 10 [ 0.01054945]
# SiLRTC: iterations = %d   difference=%f
# 11 [ 0.00819469]
# SiLRTC: iterations = %d   difference=%f
# 12 [ 0.00638455]
# SiLRTC: iterations = %d   difference=%f
# 13 [ 0.00499005]
# SiLRTC: iterations = %d   difference=%f
# 14 [ 0.00391284]
# SiLRTC: iterations = %d   difference=%f
# 15 [ 0.00307817]
# SiLRTC: iterations = %d   difference=%f
# 16 [ 0.00242927]
# SiLRTC: iterations = %d   difference=%f
# 17 [ 0.00192304]
# SiLRTC: iterations = %d   difference=%f
# 18 [ 0.0015267]
# SiLRTC: iterations = %d   difference=%f
# 19 [ 0.00121533]
# SiLRTC: iterations = %d   difference=%f
# 20 [ 0.00096987]
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/silrtc.py:45: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if Omega==None:
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/halrtc.py:49: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if Omega==None:
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/TNCP.py:33: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if omega==None:
# SiLRTC: iterations = %d   difference=%f
# 21 [ 0.00077575]
# SiLRTC: iterations = %d   difference=%f
# 22 [ 0.00062176]
# SiLRTC: iterations = %d   difference=%f
# 23 [ 0.00049926]
# SiLRTC: iterations = %d   difference=%f
# 24 [ 0.00040156]
# SiLRTC: iterations = %d   difference=%f
# 25 [ 0.00032345]
# SiLRTC: iterations = %d   difference=%f
# 26 [ 0.00026088]
# SiLRTC: iterations = %d   difference=%f
# 27 [ 0.00021065]
# SiLRTC: iterations = %d   difference=%f
# 28 [ 0.00017026]
# SiLRTC: iterations = %d   difference=%f
# 29 [ 0.00013773]
# SiLRTC: iterations = %d   difference=%f
# 30 [ 0.00011151]
# SiLRTC: iterations = %d   difference=%f
# 31 [  9.03365920e-05]
# SiLRTC: iterations = %d   difference=%f
# 32 [  7.32270659e-05]
# SiLRTC: iterations = %d   difference=%f
# 33 [  5.93880068e-05]
# SiLRTC: iterations = %d   difference=%f
# 34 [  4.81854898e-05]
# SiLRTC: iterations = %d   difference=%f
# 35 [  3.91110179e-05]
# SiLRTC: iterations = %d   difference=%f
# 36 [  3.17559731e-05]
# SiLRTC: iterations = %d   difference=%f
# 37 [  2.57914763e-05]
# SiLRTC: iterations = %d   difference=%f
# 38 [  2.09524570e-05]
# SiLRTC: iterations = %d   difference=%f
# 39 [  1.70250104e-05]
# SiLRTC: iterations = %d   difference=%f
# 40 [  1.38363354e-05]
# SiLRTC: iterations = %d   difference=%f
# 41 [  1.12467047e-05]
# SiLRTC ends: total iterations = %d   difference=%f
#
# 42 [  9.14304178e-06]
# HaLRTC: iterations = %d   difference=%f
# 1 [ 1.10409892]
# HaLRTC ends: total iterations = %d   difference=%f
#
# 2 [ 0.]
# 0.0443944032437 0.172197389053 0.211273349158 1.0 1.0 0.00665503465727

# %% [markdown]
# #### 2. Real Problem - Image Recovery

# %%
import matplotlib.image as mpimg  # Use it to load image
import numpy as np

lena = mpimg.imread("testImg.png")
im = np.double(np.uint8(lena * 255))
im = im[0:50, 0:50, 0:3]

from pyten.tenclass import Tensor  # Use it to construct Tensor object

X1 = Tensor(im)
X0 = X1.data.copy()
X0 = Tensor(X0)
Omega1 = (im < 100) * 1.0  # Missing index Tensor
X1.data[Omega1 == 0] = 0


# Basic Tensor Completion with methods: CP-ALS, Tucker-ALS, FaLRTC, SiLRTC, HaLRTC, TNCP
from pyten.method import *

r = 10
R = [10, 10, 3]  # Rank for tucker-based methods
[T1, rX1] = cp_als(X1, r, Omega1, maxiter=100)
[T2, rX2] = tucker_als(X1, R, Omega1, maxiter=100, printitn=1)
alpha = np.array([1.0, 1.0, 1e-3])
alpha = alpha / sum(alpha)
rX3 = falrtc(X1, Omega1, maxIter=100, alpha=alpha)
rX4 = silrtc(X1, Omega1, maxIter=100, alpha=alpha)
rX5 = halrtc(X1, Omega1, maxIter=100, alpha=alpha)
self1 = TNCP(X1, Omega1, rank=r)
self1.run()

# Error Testing
from pyten.tools import tenerror

realX = X0
[Err1, ReErr11, ReErr21] = tenerror(rX1, realX, Omega1)
[Err2, ReErr12, ReErr22] = tenerror(rX2, realX, Omega1)
[Err3, ReErr13, ReErr23] = tenerror(rX3, realX, Omega1)
[Err4, ReErr14, ReErr24] = tenerror(rX4, realX, Omega1)
[Err5, ReErr15, ReErr25] = tenerror(rX5, realX, Omega1)
[Err6, ReErr16, ReErr26] = tenerror(self1.X, realX, Omega1)
print ReErr21, ReErr22, ReErr23, ReErr24, ReErr25, ReErr26
# Out:
# CP_ALS:
#
# (' Iter %2d: f = %e f-delta = %7.1e\n', 1, 1059.8401427317408)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 2, 449.10511523332798)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 3, 272.40790036761661)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 4, 191.25025479312919)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 5, 146.15606715854435)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 6, 117.81553384116341)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 7, 98.37904328543469)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 8, 84.212101057765793)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 9, 73.435950414218908)
# (' Iter %2d: f = %e f-delta = %7.1e\n',
#  Iter  94 : fit =  0.943102207912 fitdelta =  0.00364715893259
#
#  Iter  95 : fit =  0.943564364572 fitdelta =  0.00348479030109
#
#  Iter  96 : fit =  0.944538033124 fitdelta =  0.0034201900185
#
#  Iter  97 : fit =  0.945312826283 fitdelta =  0.00326030295459
#
#  Iter  98 : fit =  0.945800707257 fitdelta =  0.00318063382825
#
#  Iter  99 : fit =  0.946241227977 fitdelta =  0.00316455423579
#
#  Iter  100 : fit =  0.946931830173 fitdelta =  0.00307005327028
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/falrtc.py:49: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if alpha==None:
# FaLRTC: iterations = %d   difference=%f
# 1 [ 0.98200067]
# FaLRTC: iterations = %d   difference=%f
# 2 [ 0.18130752]
# FaLRTC: iterations = %d   difference=%f
# 3 [ 0.11578534]
# FaLRTC: iterations = %d   difference=%f
# 4 [ 0.11439379]
# FaLRTC: iterations = %d   difference=%f
# 5 [ 0.09792738]
# FaLRTC: iterations = %d   difference=%f
# 6 [ 0.06558491]
# FaLRTC: iterations = %d   difference=%f
# 7 [ 0.0456438]
# FaLRTC: iterations = %d   difference=%f
# 8 [ 0.04242659]
# FaLRTC: iterations = %d   difference=%f
# 9 [ 0.03893025]
# FaLRTC: iterations = %d   difference=%f
# 10 [ 0.03512345]
# FaLRTC: iterations = %d   difference=%f
# 11 [ 0.02476415]
# FaLRTC: iterations = %d   difference=%f
# 12 [ 0.0227531]
# FaLRTC: iterations = %d   difference=%f
# 13 [ 0.02091009]
# FaLRTC: iterations = %d   difference=%f
# 14 [ 0.01925921]
# FaLRTC: iterations = %d   difference=%f
# 15 [ 0.01399864]
# FaLRTC: iterations = %d   difference=%f
# 16 [ 0.01335942]
# FaLRTC: iterations = %d   difference=%f
# 17 [ 0.01280218]
# FaLRTC: iterations = %d   difference=%f
# 18 [ 0.01226537]
# FaLRTC: iterations = %d   difference=%f
# 19 [ 0.01172968]
# FaLRTC: iterations = %d   difference=%f
# 20 [ 0.01117603]
# FaLRTC: iterations = %d   difference=%f
# 21 [ 0.01057551]
# FaLRTC: iterations = %d   difference=%f
# 22 [ 0.00991973]
# FaLRTC: iterations = %d   difference=%f
# 23 [ 0.00725955]
# FaLRTC: iterations = %d   difference=%f
# 24 [ 0.0068715]
# FaLRTC: iterations = %d   difference=%f
# 25 [ 0.00646171]
# FaLRTC: iterations = %d   difference=%f
# 26 [ 0.00603192]
# FaLRTC: iterations = %d   difference=%f
# 27 [ 0.00559467]
# FaLRTC: iterations = %d   difference=%f
# 28 [ 0.00515277]
# FaLRTC: iterations = %d   difference=%f
# 29 [ 0.00472688]
# FaLRTC: iterations = %d   difference=%f
# 30 [ 0.00432755]
# FaLRTC: iterations = %d   difference=%f
# 31 [ 0.00396288]
# FaLRTC: iterations = %d   difference=%f
# 32 [ 0.00287203]
# FaLRTC: iterations = %d   difference=%f
# 33 [ 0.00269135]
# FaLRTC: iterations = %d   difference=%f
# 34 [ 0.00253599]
# FaLRTC: iterations = %d   difference=%f
# 35 [ 0.00239642]
# FaLRTC: iterations = %d   difference=%f
# 36 [ 0.00227136]
# FaLRTC: iterations = %d   difference=%f
# 37 [ 0.00215987]
# FaLRTC: iterations = %d   difference=%f
# 38 [ 0.00207323]
# FaLRTC: iterations = %d   difference=%f
# 39 [ 0.00200981]
# FaLRTC: iterations = %d   difference=%f
# 40 [ 0.00197105]
# FaLRTC: iterations = %d   difference=%f
# 41 [ 0.00151281]
# FaLRTC: iterations = %d   difference=%f
# 42 [ 0.00151063]
# FaLRTC: iterations = %d   difference=%f
# 43 [ 0.00151581]
# FaLRTC: iterations = %d   difference=%f
# 44 [ 0.00151816]
# FaLRTC: iterations = %d   difference=%f
# 45 [ 0.00151796]
# FaLRTC: iterations = %d   difference=%f
# 46 [ 0.00152109]
# FaLRTC: iterations = %d   difference=%f
# 47 [ 0.00152485]
# FaLRTC: iterations = %d   difference=%f
# 48 [ 0.00153099]
# FaLRTC: iterations = %d   difference=%f
# 49 [ 0.00154295]
# FaLRTC: iterations = %d   difference=%f
# 50 [ 0.00155864]
# FaLRTC: iterations = %d   difference=%f
# 51 [ 0.00157608]
# FaLRTC: iterations = %d   difference=%f
# 52 [ 0.00159607]
# FaLRTC: iterations = %d   difference=%f
# 53 [ 0.0016185]
# FaLRTC: iterations = %d   difference=%f
# 54 [ 0.00126745]
# FaLRTC: iterations = %d   difference=%f
# 55 [ 0.00128412]
# FaLRTC: iterations = %d   difference=%f
# 56 [ 0.00129878]
# FaLRTC: iterations = %d   difference=%f
# 57 [ 0.00131008]
# FaLRTC: iterations = %d   difference=%f
# 58 [ 0.00131941]
# FaLRTC: iterations = %d   difference=%f
# 59 [ 0.00132787]
# FaLRTC: iterations = %d   difference=%f
# 60 [ 0.00133498]
# FaLRTC: iterations = %d   difference=%f
# 61 [ 0.00134135]
# FaLRTC: iterations = %d   difference=%f
# 62 [ 0.00104181]
# FaLRTC: iterations = %d   difference=%f
# 63 [ 0.00104631]
# FaLRTC: iterations = %d   difference=%f
# 64 [ 0.00104961]
# FaLRTC: iterations = %d   difference=%f
# 65 [ 0.00105082]
# FaLRTC: iterations = %d   difference=%f
# 66 [ 0.00105054]
# FaLRTC: iterations = %d   difference=%f
# 67 [ 0.00104939]
# FaLRTC: iterations = %d   difference=%f
# 68 [ 0.00104727]
# FaLRTC: iterations = %d   difference=%f
# 69 [ 0.00104434]
# FaLRTC: iterations = %d   difference=%f
# 70 [ 0.00104075]
# FaLRTC: iterations = %d   difference=%f
# 71 [ 0.00103647]
# FaLRTC: iterations = %d   difference=%f
# 72 [ 0.0010311]
# FaLRTC: iterations = %d   difference=%f
# 73 [ 0.00102509]
# FaLRTC: iterations = %d   difference=%f
# 74 [ 0.00061169]
# FaLRTC: iterations = %d   difference=%f
# 75 [ 0.00061075]
# FaLRTC: iterations = %d   difference=%f
# 76 [ 0.00060995]
# FaLRTC: iterations = %d   difference=%f
# 77 [ 0.00060878]
# FaLRTC: iterations = %d   difference=%f
# 78 [ 0.00060686]
# FaLRTC: iterations = %d   difference=%f
# 79 [ 0.00060432]
# FaLRTC: iterations = %d   difference=%f
# 80 [ 0.0006015]
# FaLRTC: iterations = %d   difference=%f
# 81 [ 0.00059861]
# FaLRTC: iterations = %d   difference=%f
# 82 [ 0.00059547]
# FaLRTC: iterations = %d   difference=%f
# 83 [ 0.00059211]
# FaLRTC: iterations = %d   difference=%f
# 84 [ 0.00058853]
# FaLRTC: iterations = %d   difference=%f
# 85 [ 0.00058474]
# FaLRTC: iterations = %d   difference=%f
# 86 [ 0.00034759]
# FaLRTC: iterations = %d   difference=%f
# 87 [ 0.00034484]
# FaLRTC: iterations = %d   difference=%f
# 88 [ 0.00034267]
# FaLRTC: iterations = %d   difference=%f
# 89 [ 0.00034075]
# FaLRTC: iterations = %d   difference=%f
# 90 [ 0.00033885]
# FaLRTC: iterations = %d   difference=%f
# 91 [ 0.00033697]
# FaLRTC: iterations = %d   difference=%f
# 92 [ 0.00033516]
# FaLRTC: iterations = %d   difference=%f
# 93 [ 0.0003334]
# FaLRTC: iterations = %d   difference=%f
# 94 [ 0.00033167]
# FaLRTC: iterations = %d   difference=%f
# 95 [ 0.00032993]
# FaLRTC: iterations = %d   difference=%f
# 96 [ 0.00032818]
# FaLRTC: iterations = %d   difference=%f
# 97 [ 0.00032643]
# FaLRTC: iterations = %d   difference=%f
# 98 [ 0.00032466]
# FaLRTC: iterations = %d   difference=%f
# 99 [ 0.00032289]
# FaLRTC ends: total iterations = %d   difference=%f
#
# 100 [ 0.0003211]
# SiLRTC: iterations = %d   difference=%f
# 1 [ 0.00158505]
# SiLRTC: iterations = %d   difference=%f
# 2 [ 0.00154808]
# SiLRTC: iterations = %d   difference=%f
# 3 [ 0.00151198]
# SiLRTC: iterations = %d   difference=%f
# 4 [ 0.00147679]
# SiLRTC: iterations = %d   difference=%f
# 5 [ 0.00144256]
# SiLRTC: iterations = %d   difference=%f
# 6 [ 0.00140933]
# SiLRTC: iterations = %d   difference=%f
# 7 [ 0.00137709]
# SiLRTC: iterations = %d   difference=%f
# 8 [ 0.00134587]
# SiLRTC: iterations = %d   difference=%f
# 9 [ 0.00131566]
# SiLRTC: iterations = %d   difference=%f
# 10 [ 0.00128511]
# SiLRTC: iterations = %d   difference=%f
# 11 [ 0.00125581]
# SiLRTC: iterations = %d   difference=%f
# 12 [ 0.00122676]
# SiLRTC: iterations = %d   difference=%f
# 13 [ 0.00119899]
# SiLRTC: iterations = %d   difference=%f
# 14 [ 0.00117328]
# SiLRTC: iterations = %d   difference=%f
# 15 [ 0.00114907]
# SiLRTC: iterations = %d   difference=%f
# 16 [ 0.00112603]
# SiLRTC: iterations = %d   difference=%f
# 17 [ 0.00110398]
# SiLRTC: iterations = %d   difference=%f
# 18 [ 0.00108104]
# SiLRTC: iterations = %d   difference=%f
# 19 [ 0.00105963]
# SiLRTC: iterations = %d   difference=%f
# 20 [ 0.00103966]
# SiLRTC: iterations = %d   difference=%f
# 21 [ 0.00102079]
# SiLRTC: iterations = %d   difference=%f
# 22 [ 0.00100279]
# SiLRTC: iterations = %d   difference=%f
# 23 [ 0.00098555]
# SiLRTC: iterations = %d   difference=%f
# 24
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/silrtc.py:48: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if alpha==None:
#  [ 0.00096898]
# SiLRTC: iterations = %d   difference=%f
# 25 [ 0.00095303]
# SiLRTC: iterations = %d   difference=%f
# 26 [ 0.00093765]
# SiLRTC: iterations = %d   difference=%f
# 27 [ 0.00092278]
# SiLRTC: iterations = %d   difference=%f
# 28 [ 0.00090827]
# SiLRTC: iterations = %d   difference=%f
# 29 [ 0.00089431]
# SiLRTC: iterations = %d   difference=%f
# 30 [ 0.00088083]
# SiLRTC: iterations = %d   difference=%f
# 31 [ 0.00086711]
# SiLRTC: iterations = %d   difference=%f
# 32 [ 0.00085367]
# SiLRTC: iterations = %d   difference=%f
# 33 [ 0.00084135]
# SiLRTC: iterations = %d   difference=%f
# 34 [ 0.00082976]
# SiLRTC: iterations = %d   difference=%f
# 35 [ 0.00081871]
# SiLRTC: iterations = %d   difference=%f
# 36 [ 0.00080811]
# SiLRTC: iterations = %d   difference=%f
# 37 [ 0.00079791]
# SiLRTC: iterations = %d   difference=%f
# 38 [ 0.00078806]
# SiLRTC: iterations = %d   difference=%f
# 39 [ 0.00077855]
# SiLRTC: iterations = %d   difference=%f
# 40 [ 0.00076936]
# SiLRTC: iterations = %d   difference=%f
# 41 [ 0.00076048]
# SiLRTC: iterations = %d   difference=%f
# 42 [ 0.00075188]
# SiLRTC: iterations = %d   difference=%f
# 43 [ 0.00074357]
# SiLRTC: iterations = %d   difference=%f
# 44 [ 0.00073553]
# SiLRTC: iterations = %d   difference=%f
# 45 [ 0.00072775]
# SiLRTC: iterations = %d   difference=%f
# 46 [ 0.00072022]
# SiLRTC: iterations = %d   difference=%f
# 47 [ 0.00071291]
# SiLRTC: iterations = %d   difference=%f
# 48 [ 0.00070583]
# SiLRTC: iterations = %d   difference=%f
# 49 [ 0.000699]
# SiLRTC: iterations = %d   difference=%f
# 50 [ 0.0006924]
# SiLRTC: iterations = %d   difference=%f
# 51 [ 0.00068601]
# SiLRTC: iterations = %d   difference=%f
# 52 [ 0.00067983]
# SiLRTC: iterations = %d   difference=%f
# 53 [ 0.00067383]
# SiLRTC: iterations = %d   difference=%f
# 54 [ 0.00066802]
# SiLRTC: iterations = %d   difference=%f
# 55 [ 0.00066238]
# SiLRTC: iterations = %d   difference=%f
# 56 [ 0.0006569]
# SiLRTC: iterations = %d   difference=%f
# 57 [ 0.00065153]
# SiLRTC: iterations = %d   difference=%f
# 58 [ 0.00064634]
# SiLRTC: iterations = %d   difference=%f
# 59 [ 0.0006413]
# SiLRTC: iterations = %d   difference=%f
# 60 [ 0.0006364]
# SiLRTC: iterations = %d   difference=%f
# 61 [ 0.00063164]
# SiLRTC: iterations = %d   difference=%f
# 62 [ 0.00062701]
# SiLRTC: iterations = %d   difference=%f
# 63 [ 0.0006225]
# SiLRTC: iterations = %d   difference=%f
# 64 [ 0.00061811]
# SiLRTC: iterations = %d   difference=%f
# 65 [ 0.00061383]
# SiLRTC: iterations = %d   difference=%f
# 66 [ 0.00060966]
# SiLRTC: iterations = %d   difference=%f
# 67 [ 0.00060559]
# SiLRTC: iterations = %d   difference=%f
# 68 [ 0.00060163]
# SiLRTC: iterations = %d   difference=%f
# 69 [ 0.00059775]
# SiLRTC: iterations = %d   difference=%f
# 70 [ 0.00059397]
# SiLRTC: iterations = %d   difference=%f
# 71 [ 0.00059028]
# SiLRTC: iterations = %d   difference=%f
# 72 [ 0.00058667]
# SiLRTC: iterations = %d   difference=%f
# 73 [ 0.00058315]
# SiLRTC: iterations = %d   difference=%f
# 74 [ 0.0005797]
# SiLRTC: iterations = %d   difference=%f
# 75 [ 0.00057633]
# SiLRTC: iterations = %d   difference=%f
# 76 [ 0.00057304]
# SiLRTC: iterations = %d   difference=%f
# 77 [ 0.00056981]
# SiLRTC: iterations = %d   difference=%f
# 78 [ 0.00056665]
# SiLRTC: iterations = %d   difference=%f
# 79 [ 0.00056356]
# SiLRTC: iterations = %d   difference=%f
# 80 [ 0.00056053]
# SiLRTC: iterations = %d   difference=%f
# 81 [ 0.00055756]
# SiLRTC: iterations = %d   difference=%f
# 82 [ 0.00055465]
# SiLRTC: iterations = %d   difference=%f
# 83 [ 0.0005518]
# SiLRTC: iterations = %d   difference=%f
# 84 [ 0.00054901]
# SiLRTC: iterations = %d   difference=%f
# 85 [ 0.00054627]
# SiLRTC: iterations = %d   difference=%f
# 86 [ 0.00054358]
# SiLRTC: iterations = %d   difference=%f
# 87 [ 0.00054093]
# SiLRTC: iterations = %d   difference=%f
# 88 [ 0.00053834]
# SiLRTC: iterations = %d   difference=%f
# 89 [ 0.0005358]
# SiLRTC: iterations = %d   difference=%f
# 90 [ 0.0005333]
# SiLRTC: iterations = %d   difference=%f
# 91 [ 0.00053084]
# SiLRTC: iterations = %d   difference=%f
# 92 [ 0.00052843]
# SiLRTC: iterations = %d   difference=%f
# 93 [ 0.00052606]
# SiLRTC: iterations = %d   difference=%f
# 94 [ 0.00052373]
# SiLRTC: iterations = %d   difference=%f
# 95 [ 0.00052143]
# SiLRTC: iterations = %d   difference=%f
# 96 [ 0.00051918]
# SiLRTC: iterations = %d   difference=%f
# 97 [ 0.00051696]
# SiLRTC: iterations = %d   difference=%f
# 98 [ 0.00051478]
# SiLRTC: iterations = %d   difference=%f
# 99 [ 0.00051263]
# SiLRTC ends: total iterations = %d   difference=%f
#
# 100 [ 0.00051051]
# HaLRTC: iterations = %d   difference=%f
# 1 [ 0.55801481]
# HaLRTC: iterations = %d   difference=%f
# 2 [ 0.3161156]
# HaLRTC: iterations = %d   difference=%f
# 3 [ 0.05394449]
# HaLRTC: iterations = %d   difference=%f
# 4 [ 0.05675043]
# HaLRTC: iterations = %d   difference=%f
# 5 [ 0.05294661]
# HaLRTC: iterations = %d   difference=%f
# 6 [ 0.01998763]
# HaLRTC: iterations = %d   difference=%f
# 7 [ 0.00190643]
# HaLRTC: iterations = %d   difference=%f
# 8 [ 0.00695069]
# HaLRTC: iterations = %d   difference=%f
# 9 [ 0.00423244]
# HaLRTC: iterations = %d   difference=%f
# 10 [ 0.00085012]
# HaLRTC: iterations = %d   difference=%f
# 11 [ 0.00068266]
# HaLRTC: iterations = %d   difference=%f
# 12 [ 0.0007061]
# HaLRTC: iterations = %d   difference=%f
# 13 [ 0.00027637]
# HaLRTC: iterations = %d   difference=%f
# 14 [  2.73724130e-05]
# HaLRTC: iterations = %d   difference=%f
# 15 [  9.85224647e-05]
# HaLRTC: iterations = %d   difference=%f
# 16 [  5.90534956e-05]
# HaLRTC: iterations = %d   difference=%f
# 17 [  1.02958321e-05]
# HaLRTC: iterations = %d   difference=%f
# 18 [  1.10183869e-05]
# HaLRTC: iterations = %d   difference=%f
# 19 [  1.04063490e-05]
# HaLRTC ends: total iterations = %d   difference=%f
#
# 20 [  3.65196896e-06]
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/halrtc.py:52: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if alpha==None:
# 0.937494609509 0.894333863379 0.756331723593 0.999998266198 0.999998266198 0.923009447354

# %% [markdown]
# ### Scenario 2: Tensor Completion/Decomposition with Auxiliary Information
# #### 1. Use  AirCP Method to solve Tensor Completion With Auxiliary Similarity Matrices

# %%
from pyten.method import AirCP  # Import AirCP
from pyten.tools import create  # Import the problem creation function
import numpy as np

problem = 'auxiliary'  # Define Problem As Basic Tensor Completion Problem
siz = [20, 20, 20]  # Size of the Created Synthetic Tensor
r = [4, 4, 4]  # Rank of the Created Synthetic Tensor
miss = 0.8  # Missing Percentage
tp = 'sim'  # Define Auxiliary Information As 'Similarity Matrices'
# Construct Similarity Matrices (if 'None', then it will use the default Similarity Matrices)
# aux = [np.diag(np.ones(siz[n]-1), -1)+np.diag(np.ones(siz[n]-1), 1) for n in range(dims)]
aux = None
[X1, Omega1, sol1, sim_matrices] = create(problem, siz, r, miss, tp, aux=aux)

self = AirCP(X1, Omega1, r, simMats=sim_matrices)
self.run()
self_no_aux = AirCP(X1, Omega1, r)
self_no_aux.run()

# Error Testing
from pyten.tools import tenerror

realX = sol1.totensor()
[Err1, ReErr11, ReErr21] = tenerror(self.X, realX, Omega1)
[Err2, ReErr12, ReErr22] = tenerror(self_no_aux.X, realX, Omega1)
print ReErr11, ReErr12
# Out:
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/AirCP.py:30: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if omega==None:
# AirCP: iterations=1, difference=0.416529019925
# AirCP: iterations=21, difference=0.0163831882834
# AirCP: iterations=41, difference=0.0051274030322
# AirCP: iterations=61, difference=0.00257706359727
# AirCP: iterations=81, difference=0.00152076173665
# AirCP: iterations=101, difference=0.000960643503412
# AirCP: iterations=121, difference=0.000683031429577
# AirCP: iterations=141, difference=0.000576465463789
# AirCP: iterations=161, difference=0.000491034483778
# AirCP: iterations=181, difference=0.000398349486194
# AirCP: iterations=201, difference=0.000317611347015
# AirCP: iterations=221, difference=0.000252761979273
# AirCP: iterations=241, difference=0.000202700622423
# AirCP: iterations=261, difference=0.000165653061859
# AirCP: iterations=281, difference=0.000138390660516
# AirCP: iterations=301, difference=0.000117893174295
# AirCP: iterations=321, difference=0.000102013668139
# AirCP: iterations=341, difference=8.93220990955e-05
# AirCP: iterations=361, difference=7.88263218675e-05
# AirCP: iterations=381, difference=6.97803051272e-05
# AirCP: iterations=401, difference=6.14883029057e-05
# AirCP: iterations=421, difference=5.30834047198e-05
# AirCP: iterations=441, difference=4.35165536812e-05
# AirCP: iterations=461, difference=3.22718860447e-05
# AirCP: iterations=481, difference=2.05341664177e-05
# AirCP: iterations=1, difference=0.415020519391
# AirCP: iterations=21, difference=0.0159824279428
# AirCP: iterations=41, difference=0.00603356665907
# AirCP: iterations=61, difference=0.00331491023134
# AirCP: iterations=81, difference=0.00200865633902
# AirCP: iterations=101, difference=0.00129232082293
# AirCP: iterations=121, difference=0.000872233559696
# AirCP: iterations=141, difference=0.000604420696994
# AirCP: iterations=161, difference=0.000428994375288
# AirCP: iterations=181, difference=0.000316880267434
# AirCP: iterations=201, difference=0.000248471862634
# AirCP: iterations=221, difference=0.000207163653438
# AirCP: iterations=241, difference=0.000180462289728
# AirCP: iterations=261, difference=0.000160846501387
# AirCP: iterations=281, difference=0.000144662125315
# AirCP: iterations=301, difference=0.000130731368503
# AirCP: iterations=321, difference=0.000119051566301
# AirCP: iterations=341, difference=0.000109532684186
# AirCP: iterations=361, difference=0.000101603999287
# AirCP: iterations=381, difference=9.46319251403e-05
# AirCP: iterations=401, difference=8.80427943605e-05
# AirCP: iterations=421, difference=8.11078829555e-05
# AirCP: iterations=441, difference=7.2876071403e-05
# AirCP: iterations=461, difference=6.28581699584e-05
# AirCP: iterations=481, difference=5.17746505826e-05
# 0.126911190915 0.119271742244

# %% [markdown]
# #### 2. Use  CMTF Method to solve Tensor Completion With Coupled Matrices

# %%
from pyten.method import cmtf
from pyten.tools import create  # Import the problem creation function
import numpy as np

problem = 'auxiliary'  # Define Problem As Basic Tensor Completion Problem
siz = [20, 20, 20]  # Size of the Created Synthetic Tensor
r = [4, 4, 4]  # Rank of the Created Synthetic Tensor
miss = 0.8  # Missing Percentage
tp = 'couple'  # Define Auxiliary Information As 'Similarity Matrices'
# Construct Similarity Matrices (if 'None', then it will use the default Similarity Matrices)
dims = 3
# aux = [np.diag(np.ones(siz[n]-1), -1)+np.diag(np.ones(siz[n]-1), 1) for n in range(dims)]
aux = None
[X1, Omega1, sol1, coupled_matrices] = create(problem, siz, r, miss, tp, aux=aux)

[T1, Rec1, V1] = cmtf(X1, coupled_matrices, [1, 2, 3], r, Omega1, maxiter=500, printitn=10)
[T2, Rec2, V2] = cmtf(X1, None, None, r, Omega1, maxiter=500, printitn=10)
fit_coupled_matrices_1 = [np.dot(T1.Us[n], V1[n].T) for n in range(dims)]

# Error Testing
from pyten.tools import tenerror

realX = sol1.totensor()
[Err1, ReErr11, ReErr21] = tenerror(Rec1, realX, Omega1)
[Err1, ReErr12, ReErr22] = tenerror(Rec2, realX, Omega1)
print ReErr11, ReErr12
# Out:
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/cmtf.py:40: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if Omega == None:
# CMTF:
#
# (' Iter %2d: f = %e f-delta = %7.1e\n', 10, 1.4642199770307298)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 20, 0.95877069091683687)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 30, 1.3103240078423457)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 40, 10.12091253061689)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 50, 1.0520402960179411)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 60, 0.41177941420417152)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 70, 0.31689858976456431)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 80, 0.29324205341988702)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 90, 0.63678206544380922)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 100, 2.3622416385215375)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 110, 0.92795160370151197)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 120, 0.96567156287724432)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 130, 0.63300284395044204)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 140, 0.80176137550608928)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 150, 1.0547464599895873)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 160, 2.4466479274143365)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 170, 1.5447279270980163)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 180, 1.0042897159748814)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 190, 2.670068673747052)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 200, 1.3188894364549628)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 210, 0.6448586509275871)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 220, 0.87959891627110076)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 230, 1.0093498772727196)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 240, 0.85990134647428573)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 250, 0.97028443268255471)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 260, 0.9508275607271397)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 270, 1.4621676899975742)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 280, 2.2999221181412817)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 290, 0.67028563359620952)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 300, 0.55057043895377622)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 310, 0.82646298157390996)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 320, 0.32649193691289141)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 330, 0.19474531904604872)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 340, 0.2270006940157093)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 350, 0.25317801142639923)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 360, 0.23198477020630778)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 370, 0.16076538764579348)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 380, 0.09264475651402275)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 390, 0.10215912098251173)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 400, 0.18296678060032057)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 410, 0.15270463032234349)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 420, 0.42440373195689574)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 430, 1.1017507995066822)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 440, 1.5875426753285617)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 450, 2.02328130369323)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 460, 0.99464542384871169)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 470, 0.71520245170852648)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 480, 0.44518137849230099)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 490, 0.61980136318311485)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 500, 1.2060961378751953)
#
# CP_ALS:
#
# (' Iter %2d: f = %e f-delta = %7.1e\n', 10, 0.34923662431393937)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 20, 0.14502623126439712)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 30, 0.081014804397712456)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 40, 0.047757344563449419)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 50, 0.026419273199401815)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 60, 0.015707875378148349)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 70, 0.010558254905383434)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 80, 0.0079155454185579205)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 90, 0.0063978756266562823)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 100, 0.005417056825218397)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 110, 0.0047170174522759055)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 120, 0.0041785115356177942)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 130, 0.0037415102794408723)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 140, 0.0033735769291751228)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 150, 0.0030560342565259186)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 160, 0.0027774429624669362)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 170, 0.0025303422807670798)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 180, 0.0023095527732994586)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 190, 0.0021112644718541099)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 200, 0.0019325324735604396)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 210, 0.0017709888279826855)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 220, 0.0016246716755032309)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 230, 0.0014919194518724971)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 240, 0.0013713022310285466)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 250, 0.0012615749912472222)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 260, 0.0011616443302981095)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 270, 0.0010705437791021985)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 280, 0.00098741484663198331)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 290, 0.00091149203934970608)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 300, 0.00084209073786024196)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 310, 0.00077859719339843758)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 320, 0.00072046014061379711)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 330, 0.00066718367198171193)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 340, 0.00061832111719745347)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 350, 0.00057346973741171975)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 360, 0.00053226609055049504)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 370, 0.00049438195694927818)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 380, 0.00045952073853839205)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 390, 0.00042741426262792932)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 400, 0.00039781993461979789)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 410, 0.00037051819412220699)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 420, 0.00034531023683160444)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 430, 0.00032201597056303845)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 440, 0.00030047217872150058)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 450, 0.00028053086837109478)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 460, 0.0002620577830365508)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 470, 0.00024493106313317348)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 480, 0.00022904003888406341)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 490, 0.00021428414235912774)
# (' Iter %2d: f = %e f-delta = %7.1e\n', 500, 0.00020057192685801474)
# 0.185213505146 0.000677765300277

# %% [markdown]
# ### Scenario 3: Dynamic Tensor Decomposition/Completion

# %%
from pyten.method import onlineCP, OLSGD
from pyten.tools import create  # Import the problem creation function
from pyten.tools import tenerror
import numpy as np

problem = 'dynamic'  # Define Problem As Dynamic Tensor Completion Problem
time_steps = 50  # Define the Number of Total Time Steps
siz = np.array([[1, 50, 50] for t in range(time_steps)])
r = [4, 4, 4]  # Rank of the Created Synthetic Tensor
miss = 0.8  # Missing Percentage
# Create a Dynmaic Tensor Completion Problem
[X1, Omega1, sol1, siz, time_steps] = create(problem, siz, r, miss, timestep=time_steps)

for t in range(time_steps):
    if t == 0:  # Initial Step
        self1 = OLSGD(rank=r, mu=0.01, lmbda=0.1)  # OLSGD assume time is the first mode.
        self1.update(X1[t], Omega1[t])  # Complete the initial tensor using OLSGD method.
        # onlineCP assume time is the last mode.
        self = onlineCP(X1[t].permute([1, 2, 0]), rank=r, tol=1e-8)  # Just decompose without completion using onlineCP
    else:
        self1.update(X1[t], Omega1[t])  # Update Decomposition as well as Completion using OLSGD.
        self.update(X1[t].permute([1, 2, 0]))  # Update Decomposition of onlineCP.
    # Test Current Step OLSGD Completion Error
    realX = sol1[t].totensor()
    [Err1, ReErr11, ReErr21] = tenerror(self1.recx, realX, Omega1[t])
    print Err1, ReErr11, ReErr21
# Out:
# CP_ALS:
#
# (' Iter %2d: f = %e f-delta = %7.1e\n', 45, 0.26854398643069077, 7.8492696786724991e-09)
# 87897.7659015 3659.06184906 4083.16756707
# 31.5967728209 1.63163605562 1.79283578029
# 21.6697103723 1.07343902596 1.20695305669
# 14.8453047111 0.921637531711 1.02843990353
# 29.7614074443 0.892061988553 1.00281953919
# 30.4564855803 0.898737970436 1.005229387
# 23.9043301942 0.892873146181 0.999558356876
# 29.2369872367 0.893819795643 0.99983786939
# 22.4804324052 0.883451742058 0.99994595185
# 24.6374400473 0.920382197906 1.03982923719
# 222.431934676 6.97785045615 7.71252524086
# 77.9494895636 3.19782210682 3.55035595964
# 63.5286114706 4.09868235507 4.58484116088
# 744.625355734 23.3461647197 26.0406471512
# 115.865315763 3.53714748493 3.91779993281
# 81.3060696168 2.54044820756 2.85182871526
# 2022.04229196 48.9839625233 55.8058064755
# 58.1034800845 1.47691287183 1.65921049006
# 11.8494245699 0.802828518262 0.895055454376
# 508.500896018 14.3227177694 16.1179784099
# 152.71285022 4.72766908873 5.30454376278
# 7.50154509122 0.852835154462 0.951129048614
# /Users/xingzhao/anaconda2/envs/cs670/lib/python2.7/site-packages/pyten/method/onlineCP.py:100: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.H == None:
# 52.6033798612 1.84790751635 2.08489508361
# 10.6850272817 0.773320779715 0.852343917391
# 80.015394806 3.71889203008 4.1690376148
# 10.2188814073 0.610679988892 0.669890575615
# 7.42752715206 0.64783958839 0.720341948872
# 113.779168024 4.47733011585 4.94520900995
# 85.5410589149 3.49760031952 3.90733228405
# 14.3165958062 0.486438967479 0.543685402139
# 12.564412709 0.458118497926 0.514536637196
# 10.7723027435 0.449279621796 0.497965326583
# 139.729442725 3.50890727825 3.90692707888
# 35.4360837809 1.11429439923 1.2507458167
# 17.4218081673 0.500867574881 0.565859778014
# 12.6197467079 0.486033537887 0.546408362271
# 10.6336431878 0.471932252175 0.526770234573
# 7.52463134598 0.413698543082 0.461341437448
# 34.9128413759 1.52941008468 1.71756976226
# 762.249552079 23.6371462761 26.5503272627
# 189.104935263 6.70193456374 7.5492425421
# 593.25272934 12.7593851979 14.2871846507
# 15.6196741719 0.746891783011 0.82997486218
# 22.3725855972 1.14565279962 1.26901403055
# 15.4503786942 0.502177840167 0.562481090717
# 11.0520179886 0.528743398648 0.584358444489
# 10.532988065 0.38775193152 0.434221151098
# 11.2421622005 0.423305244302 0.476402373751
# 20.9607793557 0.650305663513 0.728129833036
# 9.87928769136 0.398462411083 0.447338978859
